# %%
import pandas as pd
import numpy as np
from check_py import check_bank_is as bis

# %%
df = pd.read_excel(r"OneDrive_1_5-29-2023/bank/algo_bis.xlsx")

# %%
df
# Out:
#      Unnamed: 0       SCN REPORT_DATE  REPORTED_DATE FREQ_CODE SECURITY_CODE
# 0             0  41625877  2021-09-30            NaN         Q           ABB  \
# 1             1  41637277  2021-09-30            NaN         Q           MBB
# 2             2  42037022  2021-12-31            NaN         Y           NAB
# 3             3  42459029  2022-06-30            NaN         Q    BAOVIETBAN
# 4             4  42644769  2022-06-30            NaN         Q           NVB
# ..          ...       ...         ...            ...       ...           ...
# 494         494     52594  2020-06-30            NaN         Q           EIB
# 495         495     52594  2020-06-30            NaN         Q           BID
# 496         496     52594  2020-06-30            NaN         Q           HDB
# 497         497     52594  2020-06-30            NaN         Q           SHB
# 498         498     52594  2020-06-30            NaN         Q           MSB
#
# ...

# %%
bis.check_bis_12(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_12
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_12, BIS_10, BIS_11]
# Index: []

# %%
bis.check_bis_14a(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_14A
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_14A, BIS_3, BIS_6, BIS_7, BIS_8, BIS_9, BIS_12, BIS_13]
# Index: []

# %%
bis.check_bis_15(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_15
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_15, BIS_14A, BIS_14]
# Index: []

# %%
bis.check_bis_17(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_17
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_17, BIS_15, BIS_16]
# Index: []

# %%
bis.check_bis_20(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_20
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_20, BIS_18, BIS_19]
# Index: []

# %%
bis.check_bis_21(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_21
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED  BIS_21         BIS_17
# 0             ABB  2021-09-30         Q       N     NaN   407895000000  \
# 1             MBB  2021-09-30         Q       N     NaN  3898303000000
# 2             NAB  2021-12-31         Y       Y     NaN  1799091000000
# 3      BAOVIETBAN  2022-06-30         Q       N     NaN    17628259860
# 4             NVB  2022-06-30         Q       Y     NaN    -6429000000
# ..            ...         ...       ...     ...     ...            ...
# 494           EIB  2020-06-30         Q       Y     NaN    94204000000
# 495           BID  2020-06-30         Q       Y     NaN  2544599000000
# 496           HDB  2020-06-30         Q       Y     NaN  1656932000000
# 497           SHB  2020-06-30         Q       Y     NaN   880487000000
# 498           MSB  2020-06-30         Q       Y     NaN   684592000000
#
#            BIS_20
# 0    -81642000000
# 1   -776090000000
# 2   -364728000000
# ...

# %%
bis.check_bis_22(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_21
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED  BIS_21        BIS_22
# 0             ABB  2021-09-30         Q       N     NaN             0  \
# 1             MBB  2021-09-30         Q       N     NaN -100037000000
# 2             NAB  2021-12-31         Y       Y     NaN             0
# 3      BAOVIETBAN  2022-06-30         Q       N     NaN             0
# 4             NVB  2022-06-30         Q       Y     NaN             0
# ..            ...         ...       ...     ...     ...           ...
# 494           EIB  2020-06-30         Q       Y     NaN             0
# 495           BID  2020-06-30         Q       Y     NaN  -65241000000
# 496           HDB  2020-06-30         Q       Y     NaN -109847000000
# 497           SHB  2020-06-30         Q       Y     NaN             0
# 498           MSB  2020-06-30         Q       Y     NaN             0
#
#            BIS_22A
# 0     326253000000
# 1    3022176000000
# 2    1434363000000
# ...

# %%
bis.check_bis_22a(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_22
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED        BIS_22         BIS_22A
# 1             MBB  2021-09-30         Q       N -100037000000   3022176000000
# 11            TCB  2021-12-31         Y       Y -363132000000  18052250000000
# 12            TCB  2021-12-31         Q       N  -91588000000   4592230000000
# 14            PVF  2021-12-31         Q       N   -7659000000     73632000000
# 20            VCB  2021-06-30         Q       Y   -4569000000   3960105000000
# ..            ...         ...       ...     ...           ...             ...
# 489           CTG  2020-06-30         Q       Y  -38593000000   3571650000000
# 490           TCB  2020-06-30         Q       Y  -72116000000   2816879000000
# 493           MBB  2020-06-30         Q       Y -127079000000   2262584000000
# 495           BID  2020-06-30         Q       Y  -65241000000   1983042000000
# 496           HDB  2020-06-30         Q       Y -109847000000   1210550000000
#
# ...

# %%
bis.check_bis_6(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_6
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_6, BIS_4, BIS_5]
# Index: []

# %%
bis.check_bis_12(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS BIS_12
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, BIS_12, BIS_10, BIS_11]
# Index: []
