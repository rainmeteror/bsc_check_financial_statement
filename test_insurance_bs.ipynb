# %%
import pandas as pd
import numpy as np
import oracledb
import os
import platform
import sys
import tomli
import datetime as dt
from check_py import check_insurance_bs as ibs

pd.set_option('float_format', '{:f}'.format)

# %%
# Assign pathlink
path_link_db_algo = r"C:\Users\tungtt1\Desktop\bsc_config\config_algo.toml"

# %%
# Import files connfiq
with open(path_link_db_algo, mode="rb") as fp:
    config_acc = tomli.load(fp)

# %%
# Set up config for Oracle SQl Developer
host = config_acc["algo_acc"]["host"]
port = config_acc["algo_acc"]["port"]
service_name = config_acc["algo_acc"]["service_name"]
user = config_acc["algo_acc"]["user"]
password = config_acc["algo_acc"]["password"]

# %%
oracledb.init_oracle_client()

# %%
# Connect to database Oracle
conn = oracledb.connect(
    user=user,
    password=password,
    dsn=host+"/"+service_name
)

c = conn.cursor()

# %%
df = pd.read_sql_query(
    """ SELECT 
    * 
    FROM INSURANCE_BALANCE_SHEET
    WHERE LENGTH(SECURITY_CODE) = 3
    ORDER BY REPORT_DATE ASC, SECURITY_CODE ASC
    """, con=conn
)
# Out:
# C:\Users\tungtt1\AppData\Local\Temp\45\ipykernel_125132\239129382.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(

# %%
# df = pd.read_excel(r"OneDrive_1_5-29-2023/insurance/algo_ibs.xlsx")

# %%
df
# Out:
#           SCN REPORT_DATE REPORTED_DATE FREQ_CODE SECURITY_CODE AUDITED  \
# 0      125289  2018-03-31          None         Q           ABI       N
# 1      125289  2018-03-31          None         Q           AIC       N
# 2      125289  2018-03-31          None         Q           BIC       N
# 3      125289  2018-03-31          None         Q           BLI       N
# 4      125289  2018-03-31          None         Q           BMI       N
# ..        ...         ...           ...       ...           ...     ...
# 334  43650065  2023-06-30          None         Q           PGI       N
# 335  43638183  2023-06-30          None         Q           PRE       N
# 336  43687937  2023-06-30          None         Q           PTI       N
# 337  43626812  2023-06-30          None         Q           PVI       N
# 338  43662254  2023-06-30          None         Q           VNR       N
#
#      MONTH_IN_PERIOD               IBS_100              IBS_110  \
# ...

# %%
ibs.check_ibs_100(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_100
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_100  \
# 0            ABI  2018-03-31         Q       N  1729164214272.000000
# 1            AIC  2018-03-31         Q       N  1075559727104.000000
# 2            BIC  2018-03-31         Q       N  3645423222784.000000
# 3            BLI  2018-03-31         Q       N  1322212655104.000000
# 4            BMI  2018-03-31         Q       N  4931058663424.000000
# 5            BVH  2018-03-31         Q       N 55138525904896.000000
# 6            MIG  2018-03-31         Q       N  2342137626624.000000
# 7            PGI  2018-03-31         Q       N  4251564113920.000000
# 8            PTI  2018-03-31         Q       N  4722453905408.000000
# 9            PVI  2018-03-31         Q       N 15626671226880.000000
# 10           VNR  2018-03-31         Q       N  5196168560640.000000
# 11           ABI  2018-06-30         Q       Y  1741371867136.000000
# ...

# %%
ibs.check_ibs_110(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_110
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_110  \
# 0             ABI  2018-03-31         Q       N   372591165440.000000
# 4             BMI  2018-03-31         Q       N   327148568576.000000
# 5             BVH  2018-03-31         Q       N 11230685167616.000000
# 7             PGI  2018-03-31         Q       N   125939113984.000000
# 8             PTI  2018-03-31         Q       N   115891560448.000000
# 11            ABI  2018-06-30         Q       Y   302620409856.000000
# 14            BLI  2018-06-30         Q       Y   310079062016.000000
# 18            PGI  2018-06-30         Q       Y   138300440576.000000
# 234           HVB  2021-12-31         Y       Y    30643223316.000000
#
#                   IBS_111             IBS_112
# 0      60745883648.000000 311845289984.000000
# 4     301603979264.000000  25544599552.000000
# 5   10681711591424.000000 548974100480.000000
# 7     122189111296.000000   3750000128.000000
# ...

# %%
ibs.check_ibs_120(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_120
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_120  \
# 0             ABI  2018-03-31         Q       N  1059271999488.000000
# 1             AIC  2018-03-31         Q       N   437305442304.000000
# 2             BIC  2018-03-31         Q       N  1836246761472.000000
# 3             BLI  2018-03-31         Q       N   734189715456.000000
# 4             BMI  2018-03-31         Q       N  2200955256832.000000
# 5             BVH  2018-03-31         Q       N 34616939380736.000000
# 6             MIG  2018-03-31         Q       N  1322969464832.000000
# 7             PGI  2018-03-31         Q       N  2433602813952.000000
# 8             PTI  2018-03-31         Q       N  2614741958656.000000
# 9             PVI  2018-03-31         Q       N  7451914010624.000000
# 10            VNR  2018-03-31         Q       N  2204285796352.000000
# 11            ABI  2018-06-30         Q       Y  1150617255936.000000
# ...

# %%
ibs.check_ibs_130(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_130
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_130  \
# 1             AIC  2018-03-31         Q       N   308813398016.000000
# 2             BIC  2018-03-31         Q       N   472859410432.000000
# 3             BLI  2018-03-31         Q       N   235188273152.000000
# 4             BMI  2018-03-31         Q       N  1096628371456.000000
# 5             BVH  2018-03-31         Q       N  5932454510592.000000
# ..            ...         ...       ...     ...                   ...
# 254           MIG  2022-03-31         Q       N   699605855536.000000
# 255           PGI  2022-03-31         Q       N   456638036091.000000
# 257           PTI  2022-03-31         Q       N   943784439444.000000
# 258           PVI  2022-03-31         Q       N 10961601287882.000000
# 259           VNR  2022-03-31         Q       N   876319976570.000000
#
#                   IBS_131             IBS_132  IBS_133  IBS_1351  \
# ...

# %%
ibs.check_ibs_131(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_131
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED              IBS_131  \
# 0            ABI  2018-03-31         Q       N   35651489792.000000
# 1            AIC  2018-03-31         Q       N  167267794944.000000
# 2            BIC  2018-03-31         Q       N  340085866496.000000
# 3            BLI  2018-03-31         Q       N  158314086400.000000
# 4            BMI  2018-03-31         Q       N  937735159808.000000
# 5            BVH  2018-03-31         Q       N 4251737915392.000000
# 6            MIG  2018-03-31         Q       N  195685351424.000000
# 7            PGI  2018-03-31         Q       N  562163941376.000000
# 8            PTI  2018-03-31         Q       N  510334468096.000000
# 9            PVI  2018-03-31         Q       N 6789084479488.000000
# 10           VNR  2018-03-31         Q       N 1223477559296.000000
# 14           BLI  2018-06-30         Q       Y  170758946816.000000
# ...

# %%
ibs.check_ibs_140(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_140
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED          IBS_140  IBS_141  \
# 234           HVB  2021-12-31         Y       Y 129276900.000000 0.000000
#
#      IBS_149
# 234 0.000000

# %%
ibs.check_ibs_150(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_150
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED             IBS_150  \
# 1            AIC  2018-03-31         Q       N  18766313472.000000
# 3            BLI  2018-03-31         Q       N  79173984256.000000
# 4            BMI  2018-03-31         Q       N 242023890944.000000
# 5            BVH  2018-03-31         Q       N 608907165696.000000
# 6            MIG  2018-03-31         Q       N  88473157632.000000
# 7            PGI  2018-03-31         Q       N 157758177280.000000
# 8            PTI  2018-03-31         Q       N 208703012864.000000
# 9            PVI  2018-03-31         Q       N 257177108480.000000
# 10           VNR  2018-03-31         Q       N 181932163072.000000
# 14           BLI  2018-06-30         Q       Y  50302164992.000000
# 15           BMI  2018-06-30         Q       Y 232544354304.000000
# 18           PGI  2018-06-30         Q       Y 206796128256.000000
# ...

# %%
ibs.check_ibs_190(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_190
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, IBS_190, IBS_191, IBS_192]
# Index: []

# %%
ibs.check_ibs_200(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_200
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_200  \
# 0             ABI  2018-03-31         Q       N   163772235776.000000
# 1             AIC  2018-03-31         Q       N   588274991104.000000
# 2             BIC  2018-03-31         Q       N  1373519740928.000000
# 3             BLI  2018-03-31         Q       N   385564672000.000000
# 4             BMI  2018-03-31         Q       N   761513705472.000000
# ..            ...         ...       ...     ...                   ...
# 330           BMI  2023-06-30         Q       N   749529851833.000000
# 331           BVH  2023-06-30         Q       N 89726114992420.000000
# 333           MIG  2023-06-30         Q       N   580380127408.000000
# 336           PTI  2023-06-30         Q       N  2811136579485.000000
# 338           VNR  2023-06-30         Q       N  2398591615400.000000
#
#                IBS_210              IBS_220             IBS_240  \
# ...

# %%
ibs.check_ibs_210(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_210
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED            IBS_210  \
# 113           PTI  2019-12-31         Y       Y 83259389178.000000
# 156           PVI  2020-09-30         Q       N 24091225283.000000
# 169           BVH  2020-12-31         Y       Y 70801065457.000000
# 180           PVI  2020-12-31         Q       N 24194552153.000000
# 190           HVB  2021-03-31         Q       N  6734482240.000000
# 196           PVI  2021-03-31         Q       N 24138871488.000000
# 202           BMI  2021-06-30         Q       Y 14969034949.000000
# 204           MIG  2021-06-30         Q       Y 15471801165.000000
# 205           PGI  2021-06-30         Q       Y 13166115541.000000
# 210           ABI  2021-09-30         Q       N  7812039046.000000
# 211           AIC  2021-09-30         Q       N 12919680319.000000
# 212           BIC  2021-09-30         Q       N 31981607668.000000
# ...

# %%
ibs.check_ibs_218(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_218
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, IBS_218, IBS_2181, IBS_2182]
# Index: []

# %%
# Check these fields
ibs.check_ibs_220(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_220
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED             IBS_220  \
# 0             ABI  2018-03-31         Q       N 125724188672.000000
# 1             AIC  2018-03-31         Q       N   6929898496.000000
# 2             BIC  2018-03-31         Q       N  28601831424.000000
# 3             BLI  2018-03-31         Q       N  28533327872.000000
# 4             BMI  2018-03-31         Q       N 398192607232.000000
# ..            ...         ...       ...     ...                 ...
# 332           IFA  2023-06-30         Q       N 382731535032.000000
# 333           MIG  2023-06-30         Q       N  75099890139.000000
# 334           PGI  2023-06-30         Q       N 635532031516.000000
# 336           PTI  2023-06-30         Q       N 383445767476.000000
# 338           VNR  2023-06-30         Q       N  17446591131.000000
#
#                 IBS_221  IBS_224             IBS_227             IBS_230
# ...

# %%
ibs.check_ibs_221(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_221
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED             IBS_221  \
# 1             AIC  2018-03-31         Q       N   6481731584.000000
# 2             BIC  2018-03-31         Q       N  21991030784.000000
# 3             BLI  2018-03-31         Q       N  17104196608.000000
# 7             PGI  2018-03-31         Q       N 240018948096.000000
# 8             PTI  2018-03-31         Q       N  75017183232.000000
# 9             PVI  2018-03-31         Q       N 186322714624.000000
# 10            VNR  2018-03-31         Q       N   4916164096.000000
# 14            BLI  2018-06-30         Q       Y  16237201408.000000
# 15            BMI  2018-06-30         Q       Y 102254911488.000000
# 18            PGI  2018-06-30         Q       Y 236981026816.000000
# 21            VNR  2018-06-30         Q       Y   4912239104.000000
# 234           HVB  2021-12-31         Y       Y   2292719620.000000
#
#                 IBS_222              IBS_223
# ...

# %%
ibs.check_ibs_224(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_224
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, IBS_224, IBS_225, IBS_226]
# Index: []

# %%
ibs.check_ibs_227(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_227
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED             IBS_227  \
# 0             ABI  2018-03-31         Q       N  61031997440.000000
# 1             AIC  2018-03-31         Q       N    448166560.000000
# 2             BIC  2018-03-31         Q       N   6610802176.000000
# 4             BMI  2018-03-31         Q       N 286437769216.000000
# 5             BVH  2018-03-31         Q       N 802202779648.000000
# 6             MIG  2018-03-31         Q       N  17086489600.000000
# 7             PGI  2018-03-31         Q       N 151605067776.000000
# 8             PTI  2018-03-31         Q       N   9336837120.000000
# 10            VNR  2018-03-31         Q       N    707229056.000000
# 11            ABI  2018-06-30         Q       Y  60824539136.000000
# 15            BMI  2018-06-30         Q       Y 285190488064.000000
# 18            PGI  2018-06-30         Q       Y 158555947008.000000
# ...

# %%
ibs.check_ibs_240(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_240
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED              IBS_240  \
# 4            BMI  2018-03-31         Q       N   72803000320.000000
# 7            PGI  2018-03-31         Q       N   83623821312.000000
# 8            PTI  2018-03-31         Q       N  115147931648.000000
# 9            PVI  2018-03-31         Q       N 1491465142272.000000
# 18           PGI  2018-06-30         Q       Y   83097878528.000000
# 20           PVI  2018-06-30         Q       Y 1482972463104.000000
#
#                 IBS_241              IBS_242
# 4    85439021056.000000  -12636022784.000000
# 7    96057876480.000000  -12434051072.000000
# 8   121055363072.000000   -5907437568.000000
# 9  1621298905088.000000 -129833787392.000000
# 18   96057876480.000000  -12959991808.000000
# 20 1621298905088.000000 -138326376448.000000

# %%
ibs.check_ibs_2421(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_2421
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED  IBS_2421  IBS_2422  \
# 3            BLI  2018-03-31         Q       N  0.000000  0.000000
# 4            BMI  2018-03-31         Q       N  0.000000  0.000000
# 7            PGI  2018-03-31         Q       N  0.000000  0.000000
# 14           BLI  2018-06-30         Q       Y  0.000000  0.000000
# 15           BMI  2018-06-30         Q       Y  0.000000  0.000000
# 18           PGI  2018-06-30         Q       Y  0.000000  0.000000
#
#              IBS_2423
# 3   1663030819.000000
# 4   8265261012.000000
# 7  29048169062.000000
# 14  2883971244.000000
# 15  2984452673.000000
# 18 22395573855.000000

# %%
ibs.check_ibs_250(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_250
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_250  \
# 0             ABI  2018-03-31         Q       N    26000058368.000000
# 1             AIC  2018-03-31         Q       N   569317392384.000000
# 2             BIC  2018-03-31         Q       N  1307138064384.000000
# 3             BLI  2018-03-31         Q       N   331017486336.000000
# 4             BMI  2018-03-31         Q       N   255251169280.000000
# 5             BVH  2018-03-31         Q       N 41601824980992.000000
# 6             MIG  2018-03-31         Q       N   380000010240.000000
# 7             PGI  2018-03-31         Q       N   224284491776.000000
# 8             PTI  2018-03-31         Q       N   759241703424.000000
# 9             PVI  2018-03-31         Q       N   751738159104.000000
# 10            VNR  2018-03-31         Q       N  1113112838144.000000
# 11            ABI  2018-06-30         Q       Y    69000060928.000000
# ...

# %%
ibs.check_ibs_270(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_270
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_270  \
# 1            AIC  2018-03-31         Q       N  1663834652672.000000
# 4            BMI  2018-03-31         Q       N  5692572303360.000000
# 6            MIG  2018-03-31         Q       N  3187527385088.000000
# 7            PGI  2018-03-31         Q       N  5000720285696.000000
# 8            PTI  2018-03-31         Q       N  5746609094656.000000
# 9            PVI  2018-03-31         Q       N 19974598950912.000000
# 10           VNR  2018-03-31         Q       N  6429548216320.000000
# 11           ABI  2018-06-30         Q       Y  1950595809280.000000
# 14           BLI  2018-06-30         Q       Y  1701848416256.000000
# 15           BMI  2018-06-30         Q       Y  5602683125760.000000
# 18           PGI  2018-06-30         Q       Y  5261001490432.000000
# 20           PVI  2018-06-30         Q       Y 21756544811008.000000
# ...

# %%
ibs.check_ibs_300(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_300
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED                IBS_300  \
# 1             AIC  2018-03-31         Q       N    843383242752.000000
# 2             BIC  2018-03-31         Q       N   2866273583104.000000
# 3             BLI  2018-03-31         Q       N   1042140889088.000000
# 4             BMI  2018-03-31         Q       N   3495161757696.000000
# 5             BVH  2018-03-31         Q       N  84420241391616.000000
# 6             MIG  2018-03-31         Q       N   2285237174272.000000
# 7             PGI  2018-03-31         Q       N   3604296499200.000000
# 8             PTI  2018-03-31         Q       N   3813958221824.000000
# 9             PVI  2018-03-31         Q       N  12713236365312.000000
# 10            VNR  2018-03-31         Q       N   3645910548480.000000
# 14            BLI  2018-06-30         Q       Y   1032488026112.000000
# 15            BMI  2018-06-30         Q       Y   3380506001408.000000
# ...

# %%
ibs.check_ibs_310(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_310
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_310  \
# 0             ABI  2018-03-31         Q       N  1192792293376.000000
# 1             AIC  2018-03-31         Q       N   843280285696.000000
# 2             BIC  2018-03-31         Q       N  2864611328000.000000
# 3             BLI  2018-03-31         Q       N  1037535150080.000000
# 4             BMI  2018-03-31         Q       N  3495005782016.000000
# ..            ...         ...       ...     ...                   ...
# 334           PGI  2023-06-30         Q       N  5193848183680.000000
# 335           PRE  2023-06-30         Q       N  5320400134612.000000
# 336           PTI  2023-06-30         Q       N  6902392950208.000000
# 337           PVI  2023-06-30         Q       N 19838682743208.000000
# 338           VNR  2023-06-30         Q       N  4389112406617.000000
#
#                 IBS_311              IBS_312             IBS_313  \
# ...

# %%
ibs.check_ibs_312(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_312
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED              IBS_312  \
# 0            ABI  2018-03-31         Q       N   82503704576.000000
# 1            AIC  2018-03-31         Q       N  140940492800.000000
# 2            BIC  2018-03-31         Q       N  373627486208.000000
# 3            BLI  2018-03-31         Q       N  130446336000.000000
# 4            BMI  2018-03-31         Q       N  758867755008.000000
# 5            BVH  2018-03-31         Q       N 2083017588736.000000
# 6            MIG  2018-03-31         Q       N  206165508096.000000
# 7            PGI  2018-03-31         Q       N  316696100864.000000
# 8            PTI  2018-03-31         Q       N  498582224896.000000
# 9            PVI  2018-03-31         Q       N 2041102204928.000000
# 10           VNR  2018-03-31         Q       N 1009723441152.000000
# 11           ABI  2018-06-30         Q       Y   78173782016.000000
# ...

# %%
ibs.check_ibs_3281(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_3281
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED  IBS_3281  IBS_3282  IBS_3283
# 156           PVI  2020-09-30         Q       N       NaN       NaN       NaN
# 169           BVH  2020-12-31         Y       Y       NaN       NaN       NaN
# 180           PVI  2020-12-31         Q       N       NaN       NaN       NaN
# 190           HVB  2021-03-31         Q       N       NaN       NaN       NaN
# 196           PVI  2021-03-31         Q       N       NaN       NaN       NaN
# 202           BMI  2021-06-30         Q       Y       NaN       NaN       NaN
# 204           MIG  2021-06-30         Q       Y       NaN       NaN       NaN
# 205           PGI  2021-06-30         Q       Y       NaN       NaN       NaN
# 210           ABI  2021-09-30         Q       N       NaN       NaN       NaN
# 211           AIC  2021-09-30         Q       N       NaN       NaN       NaN
# 212           BIC  2021-09-30         Q       N       NaN       NaN       NaN
# ...

# %%
ibs.check_ibs_329(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_329
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_329  \
# 156           PVI  2020-09-30         Q       N 11255789090278.000000
# 180           PVI  2020-12-31         Q       N 10592051884760.000000
# 190           HVB  2021-03-31         Q       N    92487922605.000000
# 196           PVI  2021-03-31         Q       N 11135886629137.000000
# 202           BMI  2021-06-30         Q       Y  2789478024428.000000
# 204           MIG  2021-06-30         Q       Y  2639899924775.000000
# 205           PGI  2021-06-30         Q       Y  4037040342710.000000
# 210           ABI  2021-09-30         Q       N  1684997904202.000000
# 211           AIC  2021-09-30         Q       N  1606795967710.000000
# 212           BIC  2021-09-30         Q       N  2866425291235.000000
# 213           BLI  2021-09-30         Q       N   936429460490.000000
# 214           BMI  2021-09-30         Q       N  3876341148170.000000
# ...

# %%
ibs.check_ibs_330(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_330
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED                IBS_330  \
# 1             AIC  2018-03-31         Q       N       102895216.000000
# 2             BIC  2018-03-31         Q       N      1662235520.000000
# 3             BLI  2018-03-31         Q       N      4605728256.000000
# 4             BMI  2018-03-31         Q       N       155868736.000000
# 5             BVH  2018-03-31         Q       N    154105118720.000000
# ..            ...         ...       ...     ...                    ...
# 278           BVH  2022-09-30         Q       N 142115185799283.000000
# 296           BVH  2022-12-31         Q       N 147760970588645.000000
# 297           BVH  2022-12-31         Y       Y 147889162247129.000000
# 318           BVH  2023-03-31         Q       N 152787594575751.000000
# 331           BVH  2023-06-30         Q       N 157278565566175.000000
#
#      IBS_331  IBS_3311  IBS_3312  IBS_3313  IBS_332             IBS_333  \
# ...

# %%
ibs.check_ibs_3401(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_3401
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_3401  \
# 5             BVH  2018-03-31         Q       N  58759871201280.000000
# 169           BVH  2020-12-31         Y       Y 105270361715051.000000
# 191           IFA  2021-03-31         Q       N    690742360242.000000
# 215           BVH  2021-09-30         Q       Y 119393968521088.000000
# 232           BVH  2021-12-31         Q       N 125259541393200.000000
# 234           HVB  2021-12-31         Y       Y     91956367889.000000
# 238           PGI  2021-12-31         Y       Y   3829133894759.000000
# 253           IFA  2022-03-31         Q       N    496029851924.000000
# 256           PRE  2022-03-31         Q       Y   3373470651142.000000
# 260           ABI  2022-06-30         Q       Y   1841280440032.000000
# 261           AIC  2022-06-30         Q       Y   1961473899181.000000
# 262           BIC  2022-06-30         Q       Y   2952161780135.000000
# ...

# %%
ibs.check_ibs_400(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_400
# Empty DataFrame
# Columns: [SECURITY_CODE, REPORT_DATE, FREQ_CODE, AUDITED, IBS_400, IBS_410, IBS_4219]
# Index: []

# %%
ibs.check_ibs_410(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_410
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_410  \
# 0            ABI  2018-03-31         Q       N   700144222208.000000
# 1            AIC  2018-03-31         Q       N   820438499328.000000
# 2            BIC  2018-03-31         Q       N  2152669380608.000000
# 3            BLI  2018-03-31         Q       N   665636438016.000000
# 4            BMI  2018-03-31         Q       N  2197410938880.000000
# 5            BVH  2018-03-31         Q       N 14909325705216.000000
# 6            MIG  2018-03-31         Q       N   902290276352.000000
# 7            PGI  2018-03-31         Q       N  1396423917568.000000
# 8            PTI  2018-03-31         Q       N  1932650872832.000000
# 9            PVI  2018-03-31         Q       N  7261362585600.000000
# 10           VNR  2018-03-31         Q       N  2783637929984.000000
# 11           ABI  2018-06-30         Q       Y   673013956608.000000
# ...

# %%
ibs.check_ibs_411(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_411
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED              IBS_411  \
# 0             ABI  2018-03-31         Q       N  380000010240.000000
# 1             AIC  2018-03-31         Q       N  799999983616.000000
# 2             BIC  2018-03-31         Q       N 1172768948224.000000
# 3             BLI  2018-03-31         Q       N  599999971328.000000
# 4             BMI  2018-03-31         Q       N  913540382720.000000
# 5             BVH  2018-03-31         Q       N 6804714553344.000000
# 6             MIG  2018-03-31         Q       N  799999983616.000000
# 7             PGI  2018-03-31         Q       N  887177740288.000000
# 8             PTI  2018-03-31         Q       N  803957112832.000000
# 9             PVI  2018-03-31         Q       N 2342418644992.000000
# 10            VNR  2018-03-31         Q       N 1310759321600.000000
# 11            ABI  2018-06-30         Q       Y  380000010240.000000
# ...

# %%
ibs.check_ibs_421(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_421
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED              IBS_421  \
# 0            ABI  2018-03-31         Q       N  202460758016.000000
# 1            AIC  2018-03-31         Q       N    9453371392.000000
# 2            BIC  2018-03-31         Q       N  233299099648.000000
# 3            BLI  2018-03-31         Q       N   50950475776.000000
# 4            BMI  2018-03-31         Q       N  199508951040.000000
# 5            BVH  2018-03-31         Q       N 3230937907200.000000
# 6            MIG  2018-03-31         Q       N   76884680704.000000
# 7            PGI  2018-03-31         Q       N   49528528896.000000
# 8            PTI  2018-03-31         Q       N  229687656448.000000
# 9            PVI  2018-03-31         Q       N  965363171328.000000
# 10           VNR  2018-03-31         Q       N  544854048768.000000
# 11           ABI  2018-06-30         Q       Y  136830500864.000000
# ...

# %%
ibs.check_ibs_4215(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_4215
#     SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED  IBS_4215  IBS_4216  IBS_4217  \
# 156           PVI  2020-09-30         Q       N       NaN  0.000000       NaN
# 169           BVH  2020-12-31         Y       Y       NaN  0.000000       NaN
# 180           PVI  2020-12-31         Q       N       NaN  0.000000       NaN
# 190           HVB  2021-03-31         Q       N       NaN  0.000000       NaN
# 196           PVI  2021-03-31         Q       N       NaN  0.000000       NaN
# 202           BMI  2021-06-30         Q       Y       NaN  0.000000       NaN
# 204           MIG  2021-06-30         Q       Y       NaN  0.000000       NaN
# 205           PGI  2021-06-30         Q       Y       NaN  0.000000       NaN
# 210           ABI  2021-09-30         Q       N       NaN  0.000000       NaN
# 211           AIC  2021-09-30         Q       N       NaN  0.000000       NaN
# 212           BIC  2021-09-30         Q       N       NaN  0.000000       NaN
# ...

# %%
ibs.check_ibs_430(df=df)
# Out:
# CHECK ITEM & SUB-ITEMS IBS_430
#    SECURITY_CODE REPORT_DATE FREQ_CODE AUDITED               IBS_430  \
# 0            ABI  2018-03-31         Q       N  1892936450048.000000
# 1            AIC  2018-03-31         Q       N  1663821676544.000000
# 4            BMI  2018-03-31         Q       N  5692572303360.000000
# 5            BVH  2018-03-31         Q       N 99329566048256.000000
# 6            MIG  2018-03-31         Q       N  3187527385088.000000
# 7            PGI  2018-03-31         Q       N  5000720285696.000000
# 10           VNR  2018-03-31         Q       N  6429548216320.000000
# 14           BLI  2018-06-30         Q       Y  1701848416256.000000
# 20           PVI  2018-06-30         Q       Y 21756544811008.000000
#
#                  IBS_300               IBS_400
# 0   1192792293376.000000   700144222208.000000
# 1    843383242752.000000   820438499328.000000
# 4   3495161757696.000000  2197410938880.000000
# 5  84420241391616.000000 14909325705216.000000
# ...
